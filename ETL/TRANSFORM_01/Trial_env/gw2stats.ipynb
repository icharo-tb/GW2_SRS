# %%
import csv

# %%
with open('general_stats.csv', newline='', encoding='utf8') as stats:
  csvstats = csv.reader(stats, delimiter=';')
  next(stats)
  for line in csvstats:
    print(line)
# Out:
# ['2', 'Virtuoso', ' Condi:10', 'Narcose Galaan', 'Crusheur.8329', 'Dagger', 'Focus', 'Dagger', 'Sword', '11150', '5005430', '4087', '1834772', '7063', '3170658', '21621', '9705671', '6598', '2961766', '15023', '6743905', '0', '0', '', '']
# ['2', 'Scrapper', ' Concentration:10', 'Lunariel Caelum', 'Fokker.4610', 'Hammer', '2Hand', 'Unknown', 'Unknown', '5526', '2480511', '5233', '2349175', '293', '131336', '9010', '4044761', '8558', '3841786', '452', '202975', '0', '0', '', '']
# ['2', 'Druid', ' Concentration:10 Healing:10', 'Gleah', 'fernaxv.3249', 'Axe', 'Warhorn', 'Longbow', '2Hand', '1584', '711078', '1325', '594920', '259', '116158', '2395', '1074991', '2007', '900762', '388', '174229', '0', '0', '', '']
# ['2', 'Virtuoso', '', 'Feint Fate', 'Wyrden.4713', 'Dagger', 'Sword', 'Greatsword', '2Hand', '13815', '6201517', '13404', '6017206', '411', '184311', '21290', '9557059', '20619', '9255835', '671', '301224', '0', '0', '', '']
# ...

# %%
import pandas as pd
import numpy as np

# %%
gorsekill = pd.read_csv('gorse_stats_kill.csv')
gorsekill
# Out:
#     Sub Group Profession                                      Role  \
# 0           2  Soulbeast                                  Condi:10
# 1           2  Daredevil                                       NaN
# 2           2   Renegade                          Concentration:10
# 3           2   Catalyst                                       NaN
# 4           2  Firebrand               Concentration:10 Healing:10
# 5           3  Mechanist                                       NaN
# 6           3      Druid               Concentration:10 Healing:10
# 7           3    Scourge                                  Condi:10
# 8           3  Firebrand                                  Condi:10
# 9           3  Berserker                                       NaN
# 10          2  Berserker                                       NaN
# 11          2  Soulbeast                                       NaN
# 12          2  Mechanist  Concentration:10 Healing:10 Toughness:10
# ...

# %%
gorsekill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sub Group       30 non-null     int64
#  1   Profession      30 non-null     object
#  2   Role            19 non-null     object
#  3   Name            30 non-null     object
#  4   Account         30 non-null     object
#  5   WepSet1_1       30 non-null     object
#  6   WepSet1_2       30 non-null     object
#  7   WepSet2_1       30 non-null     object
#  8   WepSet2_2       30 non-null     object
#  9   Boss DPS        30 non-null     int64
#  10  Boss DMG        30 non-null     int64
#  11  Boss Power DPS  30 non-null     int64
#  12  Boss Power DMG  30 non-null     int64
#  13  Boss Condi DPS  30 non-null     int64
#  14  Boss Condi DMG  30 non-null     int64
#  15  All DPS         30 non-null     int64
#  16  All DMG         30 non-null     int64
# ...

# %%
gorsekill.fillna(value = 'No Role')
# Out:
#     Sub Group Profession                                      Role  \
# 0           2  Soulbeast                                  Condi:10
# 1           2  Daredevil                                   No Role
# 2           2   Renegade                          Concentration:10
# 3           2   Catalyst                                   No Role
# 4           2  Firebrand               Concentration:10 Healing:10
# 5           3  Mechanist                                   No Role
# 6           3      Druid               Concentration:10 Healing:10
# 7           3    Scourge                                  Condi:10
# 8           3  Firebrand                                  Condi:10
# 9           3  Berserker                                   No Role
# 10          2  Berserker                                   No Role
# 11          2  Soulbeast                                   No Role
# 12          2  Mechanist  Concentration:10 Healing:10 Toughness:10
# ...

# %%
gorsekill.loc[:, gorsekill.columns!='Role']
# Out:
#     Sub Group Profession                Name            Account WepSet1_1  \
# 0           2  Soulbeast                Lvid          lvid.8574  Shortbow
# 1           2  Daredevil               Jerso        pitius.8603     Staff
# 2           2   Renegade          Lady Eryel       Erniebg.1859     Sword
# 3           2   Catalyst    Medivh El Blanco     BlackBull.6249    Hammer
# 4           2  Firebrand    Astrid Laudóttir         Lesha.9607       Axe
# 5           3  Mechanist   Deadly Gasai Yuno      Fabio no.4796      Mace
# 6           3      Druid              Nádrea       Starlom.1324     Staff
# 7           3    Scourge    Alice Greenthorn       CrambzZ.4892   Scepter
# 8           3  Firebrand           Amournath         razer.8147       Axe
# 9           3  Berserker            Alsrroum       Ten Mel.4812       Axe
# 10          2  Berserker            Alsrroum       Ten Mel.4812       Axe
# 11          2  Soulbeast  Chatton Des Neiges      Addriane.7869    Dagger
# ...

# %%
gorsekill.loc[:, ~gorsekill.columns.isin(['Role', 'WepSet1_1', 'WepSet1_2', 'WepSet2_1', 'WepSet2_2'])]
# Out:
#     Sub Group Profession                Name            Account  Boss DPS  \
# 0           2  Soulbeast                Lvid          lvid.8574     13448
# 1           2  Daredevil               Jerso        pitius.8603     12885
# 2           2   Renegade          Lady Eryel       Erniebg.1859      5669
# 3           2   Catalyst    Medivh El Blanco     BlackBull.6249     11352
# 4           2  Firebrand    Astrid Laudóttir         Lesha.9607      1292
# 5           3  Mechanist   Deadly Gasai Yuno      Fabio no.4796      9721
# 6           3      Druid              Nádrea       Starlom.1324      1226
# 7           3    Scourge    Alice Greenthorn       CrambzZ.4892     17226
# 8           3  Firebrand           Amournath         razer.8147     13364
# 9           3  Berserker            Alsrroum       Ten Mel.4812     10212
# 10          2  Berserker            Alsrroum       Ten Mel.4812     10587
# 11          2  Soulbeast  Chatton Des Neiges      Addriane.7869      7931
# ...

# %%
gorsekill['Sub Group'].value_counts()
# Out:
# 2    15
# 3    15
# Name: Sub Group, dtype: int64

# %%
gorsekill['Profession'].value_counts()
# Out:
# Mechanist    5
# Firebrand    4
# Soulbeast    3
# Catalyst     3
# Berserker    3
# Daredevil    2
# Renegade     2
# Druid        2
# Scourge      2
# Harbinger    1
# Scrapper     1
# Mirage       1
# Virtuoso     1
# Name: Profession, dtype: int64

# %%
gorsekill['Boss DPS'].mean()
# Out:
# 9899.766666666666

# %%
gorsekill.groupby(['Profession']).max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#             Sub Group                Name            Account WepSet1_1  \
# Profession
# Berserker           3  Hellkus Galactikus       Ten Mel.4812     Sword
# Catalyst            3         Theo Slayer           Leo.4071   Unknown
# Daredevil           2             Rapiffa        pitius.8603     Staff
# Druid               3              Nádrea       Starlom.1324     Staff
# Firebrand           3        Old Bald Man         razer.8147       Axe
# Harbinger           3   Blaise Soulslaver       BONILLA.7295    Pistol
# Mechanist           3              Yltris      angryelf.9412      Mace
# Mirage              3     Gennosuke Saiki  Tommy shelby.2149       Axe
# ...

# %%
gorsefail = pd.read_csv('gorse_stats_fail.csv')
gorsefail
# Out:
#     Sub Group  Profession                                      Role  \
# 0         2.0    Renegade                          Concentration:10
# 1         2.0       Druid               Concentration:10 Healing:10
# 2         2.0   Soulbeast                                       NaN
# 3         2.0   Berserker                                       NaN
# 4         2.0   Harbinger                                  Condi:10
# 5         3.0   Soulbeast                                       NaN
# 6         3.0   Harbinger                                  Condi:10
# 7         3.0   Mechanist               Concentration:10 Healing:10
# 8         3.0     Specter                                  Condi:10
# 9         3.0    Renegade                                  Condi:10
# 10        2.0    Scrapper                                       NaN
# 11        2.0  Bladesworn                                       NaN
# 12        2.0       Druid  Concentration:10 Healing:10 Toughness:10
# ...

# %%
gorsefail.fillna(value = 'No Role')
# Out:
#    Sub Group  Profession                                      Role  \
# 0        2.0    Renegade                          Concentration:10
# 1        2.0       Druid               Concentration:10 Healing:10
# 2        2.0   Soulbeast                                   No Role
# 3        2.0   Berserker                                   No Role
# 4        2.0   Harbinger                                  Condi:10
# 5        3.0   Soulbeast                                   No Role
# 6        3.0   Harbinger                                  Condi:10
# 7        3.0   Mechanist               Concentration:10 Healing:10
# 8        3.0     Specter                                  Condi:10
# 9        3.0    Renegade                                  Condi:10
# 10       2.0    Scrapper                                   No Role
# 11       2.0  Bladesworn                                   No Role
# 12       2.0       Druid  Concentration:10 Healing:10 Toughness:10
# ...

# %%
gorsefail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sub Group       30 non-null     float64
#  1   Profession      30 non-null     object
#  2   Role            18 non-null     object
#  3   Name            30 non-null     object
#  4   Account         30 non-null     object
#  5   WepSet1_1       30 non-null     object
#  6   WepSet1_2       30 non-null     object
#  7   WepSet2_1       30 non-null     object
#  8   WepSet2_2       30 non-null     object
#  9   Boss DPS        30 non-null     float64
#  10  Boss DMG        30 non-null     float64
#  11  Boss Power DPS  30 non-null     float64
#  12  Boss Power DMG  30 non-null     float64
#  13  Boss Condi DPS  30 non-null     float64
#  14  Boss Condi DMG  30 non-null     float64
#  15  All DPS         30 non-null     float64
#  16  All DMG         30 non-null     float64
# ...

# %%
gorsefail['Profession'].value_counts()
# Out:
# Harbinger     6
# Renegade      5
# Druid         3
# Soulbeast     2
# Berserker     2
# Mechanist     2
# Scrapper      2
# Tempest       2
# Holosmith     2
# Firebrand     2
# Specter       1
# Bladesworn    1
# Name: Profession, dtype: int64

# %%
gorsefail['Time Died'].sum()
# Out:
# 29.0

# %%
gorsefail['Times Downed'].sum()
# Out:
# 25.0

# %%
gorsefail['Times Downed'].value_counts()
# Out:
# 0.0    15
# 1.0    10
# 2.0     3
# 5.0     1
# 4.0     1
# Name: Times Downed, dtype: int64

# %%
gorsefail['Boss DPS'].mean()
# Out:
# 7480.433333333333
