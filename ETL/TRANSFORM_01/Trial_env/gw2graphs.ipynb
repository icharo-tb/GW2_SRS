# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gorsefail = pd.read_csv('gorse_stats_fail.csv')
gorsefail
# Out:
#     Sub Group  Profession                                      Role  \
# 0         2.0    Renegade                          Concentration:10
# 1         2.0       Druid               Concentration:10 Healing:10
# 2         2.0   Soulbeast                                       NaN
# 3         2.0   Berserker                                       NaN
# 4         2.0   Harbinger                                  Condi:10
# 5         3.0   Soulbeast                                       NaN
# 6         3.0   Harbinger                                  Condi:10
# 7         3.0   Mechanist               Concentration:10 Healing:10
# 8         3.0     Specter                                  Condi:10
# 9         3.0    Renegade                                  Condi:10
# 10        2.0    Scrapper                                       NaN
# 11        2.0  Bladesworn                                       NaN
# 12        2.0       Druid  Concentration:10 Healing:10 Toughness:10
# ...

# %%
gorsefail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sub Group       30 non-null     float64
#  1   Profession      30 non-null     object
#  2   Role            18 non-null     object
#  3   Name            30 non-null     object
#  4   Account         30 non-null     object
#  5   WepSet1_1       30 non-null     object
#  6   WepSet1_2       30 non-null     object
#  7   WepSet2_1       30 non-null     object
#  8   WepSet2_2       30 non-null     object
#  9   Boss DPS        30 non-null     float64
#  10  Boss DMG        30 non-null     float64
#  11  Boss Power DPS  30 non-null     float64
#  12  Boss Power DMG  30 non-null     float64
#  13  Boss Condi DPS  30 non-null     float64
#  14  Boss Condi DMG  30 non-null     float64
#  15  All DPS         30 non-null     float64
#  16  All DMG         30 non-null     float64
# ...

# %%
gorsefail['Profession'].value_counts()
# Out:
# Harbinger     6
# Renegade      5
# Druid         3
# Soulbeast     2
# Berserker     2
# Mechanist     2
# Scrapper      2
# Tempest       2
# Holosmith     2
# Firebrand     2
# Specter       1
# Bladesworn    1
# Name: Profession, dtype: int64

# %%
gorsefail['All DMG'] = gorsefail['All DMG'].astype(str) # float column to string

# %%
plt.barh(gorsefail['Profession'].value_counts(), gorsefail['All DMG'].count()) #not working properly, need to double check
# Out:
# <BarContainer object of 12 artists>

# %%
harbinger = (gorsefail['Profession'] == 'Harbinger').sum()
renegade = (gorsefail['Profession'] == 'Renegade').sum()
druid = (gorsefail['Profession'] == 'Druid').sum()
soulbeast = (gorsefail['Profession'] == 'Soulbeast').sum()
berserker = (gorsefail['Profession'] == 'Berserker').sum()
mechanist = (gorsefail['Profession'] == 'Mechanist').sum()


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
prof = (harbinger, renegade, druid, soulbeast, berserker, mechanist)
y_pos = np.arange(len(prof))
performance = 3 + 10 * np.random.rand(len(prof))
error = np.random.rand(len(prof))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, prof)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('Most used classes')

plt.show() # it kind of works, needs double check
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.

# %%
harbinger = (gorsefail['Profession'] == 'Harbinger').sum()
renegade = (gorsefail['Profession'] == 'Renegade').sum()
druid = (gorsefail['Profession'] == 'Druid').sum()
soulbeast = (gorsefail['Profession'] == 'Soulbeast').sum()
berserker = (gorsefail['Profession'] == 'Berserker').sum()
mechanist = (gorsefail['Profession'] == 'Mechanist').sum()

plat_analysis = [harbinger, renegade, druid, soulbeast, berserker, mechanist]

plt.pie(plat_analysis, labels = ['Harbinger', 'Renegade', 'Druid', 'Soulbeast', 'Berserker', 'Mechanist'], shadow = True,
        colors = ['#003f5c', '#444e86', '#955196', '#dd5182', '#ff6e54', '#ffa600'], explode = (0.10,0.08,0.05,0,0,0), startangle = 90,
        autopct = '%1.1f%%') # https://learnui.design/tools/data-color-picker.html (color pallete)

plt.axis('equal')
plt.title('Class Usage')

plt.tight_layout()
plt.show() # working just fine, needs more variables in professions
