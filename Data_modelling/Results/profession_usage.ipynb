# %% [markdown]
# ### Important!
# Data is registered between May-September, this can change and vary with further updates on game classes

# %%
#pd.set_option('display.max_rows', None)

# %%
# %load_ext sql

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import dataframe_image as dfi

# %matplotlib inline

# %%
# %sql sqlite:///C:/Users/DANIEL/OneDrive/Escritorio/BD_Study/SQL/SQLite/SQLite_queries/gw2_srs.db

# %%
# %sql select * from player_info

# %%
# %%sql players_info <<
# SELECT
#     player_info.name,
#     player_info.account,
#     bosses.boss,
#     profession.professions
# FROM player_info JOIN bosses JOIN profession ON player_info.boss_id = bosses.id AND player_info.profession_id = profession.id
# WHERE name NOT LIKE "Conjured%" AND name NOT LIKE "Saul%";
# Out:
#  * sqlite:///C:/Users/DANIEL/OneDrive/Escritorio/BD_Study/SQL/SQLite/SQLite_queries/gw2_srs.db
# Done.
# Returning data to local variable players_info

# %%
#df1 = pd.DataFrame(players_info)
#df1

# ^ also works ^ 

df = players_info.DataFrame()
df
# Out:
#                      name          account            boss professions
# 0          Overseer Meshi   Krzysztof.5973         Samarog   Mechanist
# 1          Schmuck Norris         Oho.8712         Samarog    Virtuoso
# 2                Side Jin  EstiaStein.7531         Samarog   Mechanist
# 3           Katty Softpaw    Arcturus.8109         Samarog   Soulbeast
# 4          Toxycos Nykhos       Nykho.5386         Samarog   Firebrand
# ...                   ...              ...             ...         ...
# 19070  Mookojenkaakottaja    Mustakyy.4903  Cardinal Sabir   Mechanist
# 19071    Horracio Carillo    mooseman.3048  Cardinal Sabir   Mechanist
# 19072   Blitzara Bernhart       Blitz.3627  Cardinal Sabir   Firebrand
# 19073             Skipper  Ben Sation.8913  Cardinal Sabir   Firebrand
# 19074         Agent Seyka       Seyka.8215  Cardinal Sabir   Daredevil
#
# [19075 rows x 4 columns]

# %%
gen_class = df['professions'].value_counts().to_frame()
gen_class
# Out:
#                    professions
# Mechanist                 5906
# Firebrand                 2494
# Virtuoso                  1738
# Scourge                    991
# Soulbeast                  730
# Druid                      620
# Specter                    568
# Mirage                     558
# Scrapper                   539
# Herald                     496
# Harbinger                  397
# Daredevil                  376
# Bladesworn                 367
# Renegade                   310
# Tempest                    308
# Weaver                     210
# Berserker                  209
# Deadeye                    181
# Chronomancer               172
# Reaper                     148
# Holosmith                  131
# Dragonhunter               128
# Willbender                  96
# Catalyst                    91
# Vindicator                  87
# Spellbreaker                79
# Untamed                     78
# Core Engineer               23
# Core Warrior                13
# ...

# %%
classes = df['professions'].value_counts(normalize=True).round(5).astype(str) + '%'
per = classes.to_frame()

# %%
dfi.export(per, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\class_percentage.png')

# %%
df['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %%
vg = df.loc[df['boss']=='Vale Guardian']
gors = df.loc[df['boss']=='Gorseval The Multifarious']
sab = df.loc[df['boss']=='Sabetha the Saboteur']
sloth = df.loc[df['boss']=='Slothasor']
matt = df.loc[df['boss']=='Matthias Gabrel']
kc = df.loc[df['boss']=='Keep Construct']
xera = df.loc[df['boss']=='Xera']
cairn = df.loc[df['boss']=='Cairn the Indomitable']
mo = df.loc[df['boss']=='Mursaat Overseer']
sam = df.loc[df['boss']=='Samarog']
dei = df.loc[df['boss']=='Deimos']
sh = df.loc[df['boss']=='Soulless Horror']
dhuum = df.loc[df['boss']=='Dhuum']
ca = df.loc[df['boss']=='Conjured Amalgamate']
twins = df.loc[df['boss']=='Twin Largos']
qadim = df.loc[df['boss']=='Qadim']
adina = df.loc[df['boss']=='Cardinal Adina']
sabir = df.loc[df['boss']=='Cardinal Sabir']
prlqadim = df.loc[df['boss']=='Qadim the Peerless']

# %% [markdown]
# # VG

# %%
df_vg = vg['professions'].value_counts().to_frame()
dfi.export(df_vg, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\vg_prof_df.png')

# %%
vg['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # GORS

# %%
df_gors = gors['professions'].value_counts().to_frame()
dfi.export(df_gors, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\gors_prof_df.png')

# %%
gors['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # SAB

# %%
df_sab = sab['professions'].value_counts().to_frame()
dfi.export(df_sab, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\sab_prof_df.png')

# %%
sab['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # SLOTH

# %%
df_sloth = sloth['professions'].value_counts().to_frame()
dfi.export(df_sloth, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\sloth_prof_df.png')

# %%
sloth['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # MATT

# %%
df_matt = matt['professions'].value_counts().to_frame()
dfi.export(df_matt, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\matt_prof_df.png')

# %%
matt['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # KC

# %%
df_kc = kc['professions'].value_counts().to_frame()
dfi.export(df_kc, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\kc_prof_df.png')

# %%
kc['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # XERA

# %%
df_xera = xera['professions'].value_counts().to_frame()
dfi.export(df_xera, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\xera_prof_df.png')

# %%
xera['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # CAIRN

# %%
df_cairn = cairn['professions'].value_counts().to_frame()
dfi.export(df_cairn, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\cairn_prof_df.png')

# %%
cairn['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # MO

# %%
df_mo = mo['professions'].value_counts().to_frame()
dfi.export(df_mo, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\mo_prof_df.png')

# %%
mo['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # SAM

# %%
df_sam = sam['professions'].value_counts().to_frame()
dfi.export(df_sam, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\sam_prof_df.png')

# %%
sam['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # DEI

# %%
df_dei = dei['professions'].value_counts().to_frame()
dfi.export(df_dei, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\dei_prof_df.png')

# %%
dei['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # SH

# %%
df_sh = sh['professions'].value_counts().to_frame()
dfi.export(df_sh, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\sh_prof_df.png')

# %%
sh['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # DHUUM

# %%
df_dhuum = dhuum['professions'].value_counts().to_frame()
dfi.export(df_dhuum, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\dhuum_prof_df.png')

# %%
dhuum['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # CA

# %%
df_ca = ca['professions'].value_counts().to_frame()
dfi.export(df_ca, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\ca_prof_df.png')

# %%
ca['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # TWINS

# %%
df_twins = twins['professions'].value_counts().to_frame()
dfi.export(df_twins, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\twins_prof_df.png')

# %%
twins['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # QADIM

# %%
df_q1 = qadim['professions'].value_counts().to_frame()
dfi.export(df_q1, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\q1_prof_df.png')

# %%
qadim['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # ADINA

# %%
df_adina = adina['professions'].value_counts().to_frame()
dfi.export(df_adina, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\adina_prof_df.png')

# %%
adina['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # SABIR

# %%
df_sabir = sabir['professions'].value_counts().to_frame()
dfi.export(df_sabir, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\sabir_prof_df.png')

# %%
sabir['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# # PRLQADIM

# %%
df_prlqadim = prlqadim['professions'].value_counts().to_frame()
dfi.export(df_prlqadim, r'C:\Users\DANIEL\workspace\gw2_srs\GW2_SRS\Data_modelling\Assets\prlqadim_prof_df.png')

# %%
prlqadim['professions'].value_counts(ascending=True).plot(kind='barh')
plt.show()
